# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourav-Manik/Python_for_Data_Science/blob/main/Decision_Tree_C5_0_CART.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets  
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import  DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
# import some data to play with
iris = pd.read_csv('/content/Iris data.csv',index_col=0)

# %%
iris.head()
# Out:
#               sepal_width  petal_length  petal_width species
# sepal_length
# 5.1                   3.5           1.4          0.2  setosa
# 4.9                   3.0           1.4          0.2  setosa
# 4.7                   3.2           1.3          0.2  setosa
# 4.6                   3.1           1.5          0.2  setosa
# 5.0                   3.6           1.4          0.2  setosa

# %%
#Complete Iris dataset
label_encoder = preprocessing.LabelEncoder()
iris['species']= label_encoder.fit_transform(iris['species'])

# %%
x=iris.iloc[:,0:4]
y=iris['species']

# %%
x
# Out:
#               sepal_width  petal_length  petal_width  species
# sepal_length
# 5.1                   3.5           1.4          0.2        0
# 4.9                   3.0           1.4          0.2        0
# 4.7                   3.2           1.3          0.2        0
# 4.6                   3.1           1.5          0.2        0
# 5.0                   3.6           1.4          0.2        0
# ...                   ...           ...          ...      ...
# 6.7                   3.0           5.2          2.3        2
# 6.3                   2.5           5.0          1.9        2
# 6.5                   3.0           5.2          2.0        2
# 6.2                   3.4           5.4          2.3        2
# 5.9                   3.0           5.1          1.8        2
#
# [150 rows x 4 columns]

# %%
y
# Out:
# sepal_length
# 5.1    0
# 4.9    0
# 4.7    0
# 4.6    0
# 5.0    0
#       ..
# 6.7    2
# 6.3    2
# 6.5    2
# 6.2    2
# 5.9    2
# Name: species, Length: 150, dtype: int64

# %%
iris['species'].unique()
# Out:
# array([0, 1, 2])

# %%
iris.species.value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: species, dtype: int64

# %%
colnames = list(iris.columns)
colnames
# Out:
# ['sepal_width', 'petal_length', 'petal_width', 'species']

# %%
# Splitting data into training and testing data set
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=40)

# %% [markdown]
# ### Building Decision Tree Classifier using Entropy Criteria

# %%
model = DecisionTreeClassifier(criterion = 'entropy',max_depth=3)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
#PLot the decision tree
tree.plot_tree(model);

# %%
fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
cn=['setosa', 'versicolor', 'virginica']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(model,
               feature_names = fn, 
               class_names=cn,
               filled = True);

# %%
#Predicting on test data
preds = model.predict(x_test) # predicting on test data set 
pd.Series(preds).value_counts() # getting the count of each category
# Out:
# 1    12
# 2    10
# 0     8
# dtype: int64

# %%
preds
# Out:
# array([0, 1, 2, 2, 1, 2, 1, 1, 1, 0, 1, 0, 0, 2, 1, 2, 2, 2, 1, 1, 2, 2,
#        1, 0, 1, 0, 0, 2, 0, 1])

# %%
pd.crosstab(y_test,preds) # getting the 2 way table to understand the correct and wrong predictions
# Out:
# col_0    0   1   2
# species
# 0        8   0   0
# 1        0  12   0
# 2        0   0  10

# %%
# Accuracy 
np.mean(preds==y_test)
# Out:
# 1.0

# %% [markdown]
# ### Building Decision Tree Classifier (CART) using Gini Criteria

# %%
from sklearn.tree import DecisionTreeClassifier
model_gini = DecisionTreeClassifier(criterion='gini', max_depth=3)

# %%
model_gini.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
#Prediction and computing the accuracy
pred=model.predict(x_test)
np.mean(preds==y_test)
# Out:
# 1.0

# %% [markdown]
# #### Decision Tree Regression Example

# %%
# Decision Tree Regression
from sklearn.tree import DecisionTreeRegressor

# %%
array = iris.values
X = array[:,0:3]
y = array[:,3]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %%
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
#Find the accuracy
model.score(X_test,y_test)
# Out:
# 0.9351070733290071
